# %%
# !pip install datasets
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/25.3 MB 3.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.3/25.3 MB 3.4 MB/s eta 0:00:08
#    --- ------------------------------------ 2.1/25.3 MB 3.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.9/25.3 MB 3.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.4/25.3 MB 3.3 MB/s eta 0:00:07
#    ------ --------------------------------- 4.2/25.3 MB 3.3 MB/s eta 0:00:07
#    ------- -------------------------------- 4.7/25.3 MB 3.3 MB/s eta 0:00:07
#    -------- ------------------------------- 5.5/25.3 MB 3.3 MB/s eta 0:00:07
#    --------- ------------------------------ 6.0/25.3 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.8/25.3 MB 3.2 MB/s eta 0:00:06
# ...

# %%
from datasets import load_from_disk
saved_dataset = load_from_disk(r"C:\Users\nesil.bor\Desktop\Folders\master\DI725\DI725_termproject_2030336\data\risc_processed")
for i in range(100):
    print(saved_dataset[-5+i]['caption'])  # Print the last 5 captions (likely augmented ones)
# Out:
# a large green lake surrounded by a large white building
# a large green lake surrounded by trees
# an aerial view of the site of the proposed water treatment facility
# a large lake surrounded by a forest
# the site of the former school in the town of st louis
# A gray plane on the runway and the lawn beside .
# Three small planes parked in a line on the airport and a big plane behind them .
# A plane parked in a line on the airport with some marks .
# A small plane and a big plane parked next to boarding bridges .
# Two planes parked next to boarding bridges .
# Three planes parked next to boarding bridges of the striped terminal .
# Three planes parked on the open area .
# A plane parked on the open area and the passing plane behind it .
# A plane with the red mark and a  plane parked next to a boarding bridge while some facilities around them .
# A plane parked on the airport while some orange facilities and  cars around them .
# Four planes parked at three airports .
# ...
